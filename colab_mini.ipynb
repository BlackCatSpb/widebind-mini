# %% [markdown]
# <a href="https://colab.research.google.com/github/BlackCatSpb/widebind-mini/blob/master/colab_mini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WideBind Mini — Colab Training (T4, 16 GB)
# 4.3M params (12 layers, D=896, G=8, staircase k=[8,16,32]).
# Sigmoid-based routing (no softmax), Fibonacci-initialized signal weights, learnable VSA timescales.
# Per-expert dynamic read/write, adaptive controller, mirror LR scheduler with val-loss damping.
#
# **Before running:** upload to Google Drive:
# - `widebind_data/` with `core/`, `train.py` and `token_stream_*_clean.bin`

# %%
# --- 1. Mount Drive ---
from google.colab import drive
drive.mount('/content/drive')
DRIVE = '/content/drive/MyDrive/widebind_data'
# Out:
# Mounted at /content/drive

# %%
# --- 2. Find code folder ---
import sys, os, shutil, glob, gc, time, math, re, subprocess
import torch; import torch.nn.functional as F; import numpy as np

SRC = None
# Git pull latest code
repo_path = os.path.join(DRIVE, 'WideBand Mini')
if os.path.isdir(os.path.join(repo_path, '.git')):
    subprocess.run(['git', '-C', repo_path, 'fetch', '--all'], capture_output=True)
    subprocess.run(['git', '-C', repo_path, 'reset', '--hard', 'origin/master'], capture_output=True)
    print(f'Git sync: {repo_path}')
elif os.path.isdir(os.path.join(os.path.dirname(DRIVE), 'WideBand Mini', '.git')):
    parent = os.path.dirname(DRIVE)
    repo_path = os.path.join(parent, 'WideBand Mini')
    subprocess.run(['git', '-C', repo_path, 'fetch', '--all'], capture_output=True)
    subprocess.run(['git', '-C', repo_path, 'reset', '--hard', 'origin/master'], capture_output=True)
    print(f'Git sync: {repo_path}')

for d in [os.path.join(DRIVE, 'mini_code'), DRIVE]:
    if os.path.isdir(os.path.join(d, 'core')) and os.path.isfile(os.path.join(d, 'train.py')):
        SRC = d; break
if SRC is None:
    for root, dirs, _ in os.walk(DRIVE, topdown=True):
        for d in dirs:
            p = os.path.join(root, d)
            if os.path.isdir(os.path.join(p, 'core')) and os.path.isfile(os.path.join(p, 'train.py')):
                SRC = p; break
        if SRC: break
if SRC is None:
    raise FileNotFoundError(f'core/ not found in {DRIVE}')
sys.path.insert(0, SRC)
print(f'Code: {SRC}')
# Out:
# Git sync: /content/drive/MyDrive/widebind_data/WideBand Mini
# Code: /content/drive/MyDrive/widebind_data/WideBand Mini

# %%
# --- 3. Imports ---
from core import WideBandConfig, WideBindStack, MirrorLRScheduler, AdaptiveController
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device: {device}')
# Out:
# Device: cuda

# %%
# --- 4. Config ---
# Per-expert w_q_dyn/w_i_dyn/w_d_pen/w_bind_gate always on (no flag).
# Staircase k: [8,16,32] by layer depth third.
cfg = WideBandConfig(
    D=896, n_layers=12, bind_K=32,
    mlp_groups=8, mlp_expand=4,
    vocab=50000, seq_len=512, lr=3e-4, max_steps=300000,
    grad_clip=0.5, conv_kernel=48,
    data_dir=DRIVE,
    save_dir=os.path.join(DRIVE, 'checkpoints'),
    log_dir=os.path.join(DRIVE, 'logs'),
    bind_twist_mode='shift',
    accum_steps=8,
    private_mem=False,  # off by default for cleaner dynamics
    div_weight=0.087,
    ranking_weight=0.01,
    log_scale_l2_weight=0.01,
)
print(f'D={cfg.D} L={cfg.n_layers} G={cfg.mlp_groups} K={cfg.bind_K} seq={cfg.seq_len}')
print(f'  warmup={cfg.warmup_steps} eval={cfg.eval_interval} save={cfg.save_interval}')
# Out:
# D=896 L=12 G=8 K=32 seq=512
#   warmup=101 eval=233 save=987

# %%
# --- 5. Model on CPU (sanity) ---
model = WideBindStack(cfg)
print(f'Params: {model.param_count():,} ({model.param_count()/1e6:.2f}M)')
x = torch.randint(0, cfg.vocab, (1, 16))
h = model.embed_tokens(x)
out, state, gs = model(h)
assert out.shape[-1] == cfg.D
print(f'Forward: OK, out.std={out.std():.4f}')
del x, h, out, state, gs; gc.collect()
# Out:
# Params: 12,749,608 (12.75M)
# Forward: OK, out.std=0.9997
# 30

# %%
# --- 6. Data streams ---
stream_files = sorted(glob.glob(os.path.join(DRIVE, 'token_stream_*_clean.bin')))
if not stream_files:
    stream_files = sorted(glob.glob(os.path.join(DRIVE, 'token_stream_*.bin')))
if not stream_files:
    raise FileNotFoundError(f'token_stream_*.bin not found in {DRIVE}')
streams = [np.memmap(f, dtype=np.uint16, mode='r') for f in stream_files]
print(f'Streams: {len(streams)} files, {sum(len(s) for s in streams):,} tokens')

class StreamReader:
    def __init__(self, streams, S, B):
        self.streams = streams; self.S = S; self.B = B
        self.si = 0; self.off = 0
    def get_batch(self):
        s = self.streams[self.si]
        need = self.B * self.S + 1
        if self.off + need > len(s):
            self.off = 0; self.si = (self.si + 1) % len(self.streams)
            s = self.streams[self.si]
        ch = s[self.off:self.off+need]
        x = torch.from_numpy(ch[:self.B*self.S].copy()).long().view(self.B, self.S)
        y = torch.from_numpy(ch[1:self.B*self.S+1].copy()).long().view(self.B, self.S)
        self.off += self.B * self.S
        return x, y
# Out:
# Streams: 2 files, 3,964,570,754 tokens

# %%
# --- 7. Batch size ---
B = 2
cfg.batch_size = B
reader = StreamReader(streams, cfg.seq_len, B)
print(f'Batch size: {B}')
# Out:
# Batch size: 2

# %%
# --- 8. Model to GPU + Optimizer (FP32) ---
model = model.to(device)
# Phase tracking state (EMA-based adaptive threshold)
model._phase_ratio_ema = [0.0] * cfg.n_layers
model._phase_ratio_std = [1.0] * cfg.n_layers
groups = model.param_groups()
optimizer = torch.optim.AdamW(groups, betas=(0.9, 0.95))
scheduler = MirrorLRScheduler(model, optimizer, cfg=cfg)
accum = getattr(cfg, 'accum_steps', 1)
mem_free, mem_total = torch.cuda.mem_get_info()
print(f'GPU: {mem_free/1e9:.2f}/{mem_total/1e9:.2f} GB free')
print(f'Optimizer ready, accum={accum}')
# Out:
# GPU: 15.41/15.64 GB free
# Optimizer ready, accum=8

# %%
# --- 9. Resume ---
start_step = 0; best_val = float('inf')
os.makedirs(cfg.save_dir, exist_ok=True)

def step_key(p):
    m = re.search(r'step_(\\d+)', os.path.basename(p))
    return int(m.group(1)) if m else 0

ckpts = sorted(glob.glob(os.path.join(cfg.save_dir, '*.pt')), key=step_key)
loaded = False
if ckpts:
    try:
        ckpt = torch.load(ckpts[-1], map_location='cpu', weights_only=False)
        has_nan = False
        for k, v in ckpt['model'].items():
            if v.is_floating_point() and (v.isnan().any() or v.isinf().any()):
                print(f'  NaN/Inf in {k}')
                has_nan = True
        if has_nan:
            print(f'  Corrupted ckpt {os.path.basename(ckpts[-1])}, deleting')
            os.remove(ckpts[-1])
            del model
            gc.collect(); torch.cuda.empty_cache()
            model = WideBindStack(cfg).to(device)
            model._phase_ratio_ema = [0.0] * cfg.n_layers
            model._phase_ratio_std = [1.0] * cfg.n_layers
            groups = model.param_groups()
            optimizer = torch.optim.AdamW(groups, betas=(0.9, 0.95))
            scheduler = MirrorLRScheduler(model, optimizer, cfg=cfg)
            raise RuntimeError('Re-initialized from corrupted ckpt')
        miss, unexp = model.load_state_dict(ckpt['model'], strict=False)
        if 'optimizer' in ckpt:
            try: optimizer.load_state_dict(ckpt['optimizer'])
            except Exception as e: print(f'  Opt load: {e}')
        if 'scheduler' in ckpt:
            try: scheduler.load_state_dict(ckpt['scheduler'])
            except Exception as e: print(f'  Sched load: {e}')
        start_step = ckpt.get('step', 0)
        best_val = ckpt.get('best_val_loss', float('inf'))
        print(f'Resumed: step {start_step}, best={best_val:.4f}, miss={len(miss)}')
        with torch.no_grad():
            xt = torch.randint(0, cfg.vocab, (B, cfg.seq_len), device=device)
            ht = model.embed_tokens(xt)
            ot, _, _ = model(ht)
            assert not torch.isnan(ot).any(), 'NaN after resume'
            print(f'  Sanity: out.std={ot.std():.4f}')
        del ckpt, xt, ht, ot; gc.collect()
        loaded = True
    except Exception as e:
        start_step = 0
        print(f'  Fresh start: {e}')
if not loaded:
    print('Fresh start')
# Out:
# Fresh start

# %%
# --- 10. Eval ---
@torch.no_grad()
def evaluate():
    model.eval()
    total, cnt = 0.0, 0
    n = max(1, sum(len(s) for s in streams) // (B * cfg.seq_len) // len(streams))
    n = min(100, n)
    for si, s in enumerate(streams):
        off = max(len(s) // 4, B * cfg.seq_len + 1)
        state = None; gs = None
        for _ in range(n):
            if off + B * cfg.seq_len + 1 > len(s): off = 0; break
            ch = s[off:off+B*cfg.seq_len+1]
            x = torch.from_numpy(ch[:B*cfg.seq_len].copy()).long().view(B, cfg.seq_len).to(device)
            y = torch.from_numpy(ch[1:B*cfg.seq_len+1].copy()).long().view(B, cfg.seq_len).to(device)
            off += B * cfg.seq_len
            h = model.embed_tokens(x)
            out, state, gs = model(h, state, global_state=gs, adaptive=False)
            total += model.compute_loss(out, y).item(); cnt += 1
            if _ % 25 == 24: state = None; gs = None
        del state, gs; gc.collect()
    model.train()
    return total / max(cnt, 1)

# %%
# --- 11. NaN Diagnostic + component pinpoint ---
x_diag, y_diag = reader.get_batch()
x_diag = x_diag.to(device); y_diag = y_diag.to(device)
t_min = x_diag.min().item(); t_max = x_diag.max().item()
print(f'  Token range: [{t_min}, {t_max}] (vocab={cfg.vocab})')
if t_max >= cfg.vocab:
    raise ValueError(f'Token {t_max} >= vocab {cfg.vocab}')
if t_min < 0:
    raise ValueError(f'Token {t_min} < 0')

def check(x, label):
    if x.isnan().any() or x.isinf().any():
        print(f'  NaN/Inf in {label}: shape={x.shape} range=[{x.min():.2f},{x.max():.2f}]')
        return True
    return False

with torch.no_grad():
    h = model.embed_tokens(x_diag)
    if check(h, "embed"): raise RuntimeError("NaN in embed")

    layer = model.layers[0]
    B, L, D = h.shape

    # Pre-LN
    h = F.rms_norm(h, (D,), layer.pre_ln_w)
    if check(h, "rms_norm"): raise RuntimeError("NaN in rms_norm")

    # Conv
    conv_state = torch.zeros(B, D, layer.conv.padding[0], device=h.device, dtype=h.dtype)
    h_perm = h.transpose(1, 2)
    h_conv = layer.conv(torch.cat([conv_state, h_perm], dim=-1))[..., :L].transpose(1, 2)
    if check(h_conv, "conv"): raise RuntimeError("NaN in conv")
    h = h + h_conv

    # Bind
    bind_out = layer.bind(h)
    if check(bind_out, "bind"): raise RuntimeError("NaN in bind")

    # VSA memory
    S = layer._n_scales
    tau_s = layer._tau_s
    d_s = torch.exp(-1.0 / tau_s.to(h.device))
    i_gate = F.softplus(h * layer.w_i + layer.b_i)
    if check(i_gate, "igate"): raise RuntimeError("NaN in igate")
    d_mod = torch.sigmoid(h * layer.w_d + layer.b_d)
    if check(d_mod, "dmod"): raise RuntimeError("NaN in d_mod")
    d_s_vec = d_s.view(1, 1, S, 1).expand(B, L, S, D).reshape(B, L, S * D)
    d_mod_vec = d_mod.unsqueeze(2).expand(-1, -1, S, -1).reshape(B, L, S * D)
    decay = (d_s_vec * d_mod_vec).clamp(min=0.01, max=1.0)
    if check(decay, "decay"): raise RuntimeError("NaN in decay")
    mem_input = h * i_gate
    input_vec = mem_input.unsqueeze(2).expand(-1, -1, S, -1).reshape(B, L, S * D)
    eps = 1e-6
    CHUNK = 32
    decay_f32 = decay.float()
    input_vec_f32 = input_vec.float()
    def scan_chunk(b, d):
        log_a = torch.log(d.clamp(min=eps))
        log_cum = torch.cumsum(log_a, dim=1)
        cum_decay = torch.exp(log_cum)
        inv_cum = (1.0 / cum_decay.clamp(min=eps)).clamp(max=1e6)
        weighted = b * inv_cum
        cum_w = torch.cumsum(weighted, dim=1)
        intra = cum_decay * cum_w
        return intra, intra[:, -1:], cum_decay
    chunks = []
    for start in range(0, L, CHUNK):
        end = min(start + CHUNK, L)
        intra, final, cum_decay = scan_chunk(input_vec_f32[:, start:end], decay_f32[:, start:end])
        if check(intra, f"scan_chunk_{start}"): raise RuntimeError("NaN in scan")
        chunks.append((intra, final, cum_decay))
    inter_decay = torch.cat([cd[:, -1:] for _, _, cd in chunks], dim=1)
    inter_input = torch.cat([f for _, f, _ in chunks], dim=1)
    s = torch.zeros_like(inter_input[:, 0])
    cross_states = []
    for k in range(len(chunks)):
        cross_states.append(s.unsqueeze(1))
        s = inter_decay[:, k] * s + inter_input[:, k]
        if check(s, f"cross_{k}"): raise RuntimeError("NaN in cross_chunk")
    cross = torch.cat(cross_states, dim=1)

    print(f'  VSA memory scan: OK (max_cross={s.abs().max():.4f})')

    combined_pieces = []
    for k, (intra_k, _, cum_decay_k) in enumerate(chunks):
        cross_k = cross[:, k:k+1]
        combined_pieces.append(cross_k * cum_decay_k + intra_k)
    combined = torch.cat(combined_pieces, dim=1).to(h.dtype)
    if check(combined, "combined"): raise RuntimeError("NaN in combined_mem")

    mem_all = combined.view(B, L, S, D)
    w_scales = torch.sigmoid(layer.scale_w)
    mem_read = (mem_all * w_scales.unsqueeze(0).unsqueeze(0)).sum(dim=2)
    if check(mem_read, "mem_read"): raise RuntimeError("NaN in mem_read")

    # Mirror
    mirror_out, mlp_mod, mem_mod = layer.mirror(h, mem_read, global_state=None, diff=None)
    if check(mirror_out, "mirror"): raise RuntimeError("NaN in mirror")
    if check(mlp_mod, "mlp_mod"): raise RuntimeError("NaN in mlp_mod")
    if check(mem_mod, "mem_mod"): raise RuntimeError("NaN in mem_mod")

    # Post-mirror combine
    g = layer.mirror.G
    d_g = layer.mirror.d
    mm = mem_mod.unsqueeze(-1)
    hp = layer.mirror._cached_hp
    read_mod = torch.sigmoid(torch.einsum("blgk,gkd->blgd", hp, layer.w_q_dyn) / math.sqrt(layer.mirror.k))
    if check(read_mod, "read_mod"): raise RuntimeError("NaN in read_mod")
    mem_read_g = mem_read.reshape(B, L, g, d_g)
    mem_expert = mem_read_g * read_mod
    mem_modulated = (mem_expert * mm).reshape(B, L, D)
    bind_gate = torch.sigmoid(layer.w_bind_gate).unsqueeze(0).unsqueeze(0)
    bind_gated = (bind_out.reshape(B, L, g, d_g) * mm * bind_gate.unsqueeze(-1)).reshape(B, L, D)
    enhanced_base = bind_gated + mem_modulated * layer.w_mem2v
    enhanced = enhanced_base + mirror_out
    if check(enhanced, "enhanced"): raise RuntimeError("NaN in enhanced")
    h = h + enhanced
    if check(h, "h_after_enhanced"): raise RuntimeError("NaN after enhanced")

    # Spectral DCT
    h_dct = h @ layer.V_dct.T
    h = h + (h_dct * layer.lambda_k) @ layer.V_dct
    if check(h, "h_after_spectral"): raise RuntimeError("NaN after spectral")

    # MLP
    h_mlp = layer.mlp(h)
    mm2 = mlp_mod.unsqueeze(-1)
    h_mlp = (h_mlp.reshape(B, L, g, d_g) * mm2).reshape(B, L, D)
    h = h + h_mlp
    if check(h, "h_final"): raise RuntimeError("NaN at final")

    print('=== L0 component diagnostic PASS ===')
    # Clear cache
    for l in model.layers:
        l.mirror._cached_pred_error_norm = None
        l.mirror._cached_hp = None
# Out:
#   Token range: [10, 43034] (vocab=50000)
#   VSA memory scan: OK (max_cross=288.8695)
# === L0 component diagnostic PASS ===

# %%
# --- 12. Training Loop (FP32) ---
state = None; gs = None; t0 = time.time(); tokens = 0

def _detach(x):
    if x is None: return None
    if isinstance(x, torch.Tensor): return x.detach()
    if isinstance(x, (tuple, list)): return type(x)(_detach(v) for v in x)
    return x

print(f'Training: {start_step} to {cfg.max_steps}')
print(f'GPU: {torch.cuda.mem_get_info()[0]/1e9:.2f}/{torch.cuda.mem_get_info()[1]/1e9:.2f} GB')
try:
    for step in range(start_step, cfg.max_steps):
        x, y = reader.get_batch()
        x, y = x.to(device), y.to(device)

        if (y[:, -1] == 2).any() and state is not None:
            state = _detach(state)

        h = model.embed_tokens(x)
        out, state, gs = model(h, state, global_state=gs, step=step)
        if out.is_floating_point() and (out.isnan().any() or out.isinf().any()):
            for li, layer in enumerate(model.layers):
                if hasattr(layer, '_nan_at') and layer._nan_at is not None:
                    print(f'  NaN origin: {layer._nan_at}')
                    break
            else:
                print(f'  NaN in out but no layer reported origin')
            raise RuntimeError(f'NaN at step {step}')
        ce_loss, aux_dict = model.compute_losses(out, y)

        state = _detach(state); gs = _detach(gs)

        # Gradient norm-based aux scaling via autograd.grad
        ce_grads = torch.autograd.grad(ce_loss / accum, model.parameters(),
                                       retain_graph=bool(aux_dict), allow_unused=True)

        if aux_dict:
            aux_total = sum(
                v for v in aux_dict.values()
                if isinstance(v, torch.Tensor) and v.requires_grad
            ) / accum
            aux_grads = torch.autograd.grad(aux_total, model.parameters(), allow_unused=True)
            ce_list, aux_list = [], []
            for gce, gaux in zip(ce_grads, aux_grads):
                if gce is not None and gaux is not None:
                    ce_list.append(gce.flatten())
                    aux_list.append(gaux.flatten())
            if ce_list:
                ce_flat = torch.cat(ce_list)
                aux_flat = torch.cat(aux_list)
                cos_sim = F.cosine_similarity(ce_flat.unsqueeze(0), aux_flat.unsqueeze(0))
                scale = max(0, cos_sim.item()) * ce_flat.norm() / (aux_flat.norm() + 1e-8)
            else:
                scale = 0.0
        else:
            scale = 0.0

        with torch.no_grad():
            for p, cg in zip(model.parameters(), ce_grads):
                if cg is not None:
                    p.grad = cg.clone()
                else:
                    p.grad = None
            if aux_dict and scale > 0:
                for p, ag in zip(model.parameters(), aux_grads):
                    if p.grad is not None and ag is not None:
                        p.grad.add_(ag, alpha=scale)
                    elif ag is not None:
                        p.grad = ag * scale

        # Adaptive phase scaling: EMA-based mirror/base gradient balance
        phase_scales = []
        for i, layer in enumerate(model.layers):
            mirror_norm = 0.0
            base_norm = 0.0
            for p in layer.mirror_parameters:
                if p.grad is not None:
                    mirror_norm += p.grad.norm().item() ** 2
            for p in layer.base_parameters:
                if p.grad is not None:
                    base_norm += p.grad.norm().item() ** 2
            mirror_norm = mirror_norm ** 0.5
            base_norm = base_norm ** 0.5
            ratio = mirror_norm / (base_norm + 1e-8)
            ema = model._phase_ratio_ema[i]
            std = model._phase_ratio_std[i]
            model._phase_ratio_ema[i] = 0.99 * ema + 0.01 * ratio
            model._phase_ratio_std[i] = 0.99 * std + 0.01 * abs(ratio - ema)
            mir_s = 1.0 / (1.0 + math.exp(-(ratio - ema) / (std + 1e-8)))
            phase_scales.append((mir_s, ratio))
            for p in layer.mirror_parameters:
                if p.grad is not None:
                    p.grad *= mir_s
        mean_mirror_scale = sum(s[0] for s in phase_scales) / len(phase_scales)
        mean_ratio = sum(s[1] for s in phase_scales) / len(phase_scales)

        tokens += B * cfg.seq_len

        scheduler.step()
        if (step + 1) % accum == 0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)

        if step % cfg.log_interval == 0:
            dt = time.time() - t0
            try:
                idiff = torch.stack([(1.0 - l.mirror.alpha_diag.data).abs().mean() for l in model.layers]).mean().item()
                gvar = torch.stack([l.mirror._last_gates.var() for l in model.layers]).mean().item()
                ls_var = torch.stack([l.mirror.log_scale.data.var() for l in model.layers]).mean().item()
            except Exception:
                idiff = gvar = ls_var = 0.0
            lc = getattr(model, '_cached_losses', {})
            aux_str = ' '.join(f'{k}={v:.4f}' for k, v in lc.items())
            lr = scheduler.get_last_lr()[0]
            mem_gb = torch.cuda.max_memory_allocated() / 1e9 if device == 'cuda' else 0
            print(f'step={step:>6} loss={ce_loss.item():.4f} |1-a|={idiff:.4f} '
                  f'g_var={gvar:.4f} ls_var={ls_var:.4f} lr={lr:.2e} tok/s={tokens/dt:.0f} '
                  f'ms={mean_mirror_scale:.3f} mr={mean_ratio:.4f} '
                  f'mem={mem_gb:.2f}GB | {aux_str}')
            if device == 'cuda':
                torch.cuda.reset_peak_memory_stats()

        if step > 0 and step % cfg.eval_interval == 0:
            vl = evaluate()
            print(f'  EVAL step={step}: val_loss={vl:.4f} ppl={math.exp(min(vl, 20)):.2f}')
            scheduler.report_val_loss(vl)
            torch.cuda.empty_cache(); gc.collect()
            if vl < best_val:
                best_val = vl
                torch.save({'step': step, 'model': model.state_dict(),
                           'best_val_loss': best_val, 'cfg': cfg},
                          os.path.join(cfg.save_dir, 'best.pt'))
                print(f'  New best!')
            torch.save({'step': step, 'model': model.state_dict(),
                       'best_val_loss': best_val, 'cfg': cfg,
                       'optimizer': optimizer.state_dict(),
                       'scheduler': scheduler.state_dict()},
                      os.path.join(cfg.save_dir, f'eval_{step}.pt'))
            print(f'  Saved eval_{step}.pt')

        if step > 0 and step % cfg.save_interval == 0:
            ckpt = {
                'step': step, 'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'scheduler': scheduler.state_dict(),
                'best_val_loss': best_val, 'cfg': cfg,
            }
            torch.save(ckpt, os.path.join(cfg.save_dir, f'step_{step}.pt'))
            print(f'  Saved step_{step}.pt')
            del ckpt; gc.collect()

except KeyboardInterrupt:
    ckpt = {
        'step': step, 'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
        'best_val_loss': best_val, 'cfg': cfg,
    }
    path = os.path.join(cfg.save_dir, f'step_{step}.pt')
    torch.save(ckpt, path)
    print(f'\nInterrupted. Saved {path}')
# Out:
# Training: 0 to 300000
# GPU: 15.15/15.64 GB
# step=     0 loss=10.5986 |1-a|=0.1037 g_var=0.0168 ls_var=0.0388 lr=8.78e-07 tok/s=524 ms=0.590 mr=0.3892 mem=6.72GB | ce=10.5986 pred=1.6533 gate_l1=0.5323 reinforce=0.0485 balance=0.0073 div=-0.0446 ranking=42.2921 signal_ent=1.2770 ls_reg=0.0000 decorr=0.1568
# step=    55 loss=11.0746 |1-a|=0.1044 g_var=0.0070 ls_var=0.0387 lr=4.92e-05 tok/s=692 ms=0.572 mr=0.3662 mem=7.28GB | ce=11.0746 pred=10.1746 gate_l1=0.5551 reinforce=0.0520 balance=0.0028 div=-0.0445 ranking=46.3773 signal_ent=1.2770 ls_reg=0.0000 decorr=0.1770
# step=   110 loss=10.1222 |1-a|=0.1063 g_var=0.0086 ls_var=0.0385 lr=8.34e-05 tok/s=702 ms=0.552 mr=0.3652 mem=7.28GB | ce=10.1222 pred=8.3437 gate_l1=0.5448 reinforce=0.0540 balance=0.0035 div=-0.0443 ranking=47.8346 signal_ent=1.2769 ls_reg=0.0000 decorr=0.1760
# ...
